# %% [markdown]
# ## Goal
# To create visualizations commonly used in exploratory data analysis to understand data distributions. They will be categorized according to their purposes.

# %%
import numpy as np
import pandas as pd;
from matplotlib import cm

# %%
# lets gets started with some data import. 
data_path = '../input_data/forestfires.csv'

df = pd.read_csv(data_path)

# %% [markdown]
# Attribute Information:
#
# For more information, read [Cortez and Morais, 2007].
# 1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
# 2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
# 3. month - month of the year: 'jan' to 'dec'
# 4. day - day of the week: 'mon' to 'sun'
# 5. FFMC - FFMC index from the FWI system: 18.7 to 96.20
# 6. DMC - DMC index from the FWI system: 1.1 to 291.3
# 7. DC - DC index from the FWI system: 7.9 to 860.6
# 8. ISI - ISI index from the FWI system: 0.0 to 56.10
# 9. temp - temperature in Celsius degrees: 2.2 to 33.30
# 10. RH - relative humidity in %: 15.0 to 100
# 11. wind - wind speed in km/h: 0.40 to 9.40
# 12. rain - outside rain in mm/m2 : 0.0 to 6.4
# 13. area - the burned area of the forest (in ha): 0.00 to 1090.84
# (this output variable is very skewed towards 0.0, thus it may make
# sense to model with the logarithm transform).

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# Some sorting

df["Month"] = pd.to_datetime(df.month, format='%b', errors='coerce').dt.month
df = df.sort_values(by="Month")
df.head()
# Out:
#      X  Y month  day  FFMC   DMC     DC  ISI  temp   RH  wind  rain   area  \
# 104  2  4   jan  sat  82.1   3.7    9.3  2.9   5.3   78   3.1   0.0   0.00
# 379  4  5   jan  sun  18.7   1.1  171.4  0.0   5.2  100   0.9   0.0   0.00
# 96   3  4   feb  sat  83.9   8.0   30.2  2.6  12.7   48   1.8   0.0   0.00
# 59   2  2   feb  fri  86.6  13.2   43.0  5.3  12.3   51   0.9   0.0   0.00
# 202  7  4   feb  sun  83.9   8.7   32.1  2.1   8.8   68   2.2   0.0  13.05
#
#      Month
# 104      1
# 379      1
# 96       2
# 59       2
# 202      2

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area       Month
# count  517.000000  517.000000  517.000000  517.000000   517.000000  517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292    7.475822
# std      5.806625   16.317469    1.791653    0.295959    63.655818    2.275990
# min      2.200000   15.000000    0.400000    0.000000     0.000000    1.000000
# 25%     15.500000   33.000000    2.700000    0.000000     0.000000    7.000000
# 50%     19.300000   42.000000    4.000000    0.000000     0.520000    8.000000
# 75%     22.800000   53.000000    4.900000    0.000000     6.570000    9.000000
# max     33.300000  100.000000    9.400000    6.400000  1090.840000   12.000000

# %%
Lets get started with some _distribution plots_ to get an idea of what the individual data columns look like

# %% [markdown]
# ## Distribution plots

# %% [markdown]
# Lets get started with visualizing continuous variables

# %%
# import the visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import joypy

# %%
# Some basic settings, shall we. 
sns.set(rc={'figure.figsize':(15,8.27)}) # figure sizes
sns.set_style("whitegrid") # setting the style 
#sns.set_palette('colorblind') ## Always colorblind

# %% [markdown]
# In your visualizations, please always be courteous enough to set the palette to be 'Colorbind'.

# %% [markdown]
# #### 1. Histograms, Kernel Density Estimation Plots and Rug Plots

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1, ncols=3, sharey=True)


sns.distplot(df.temp, ax= ax0)# Simple default dist plot gives histogram and the kde plot
ax0.set(xlabel='Distribution of temperature', title= "using default dist plot")


sns.distplot(df.temp, hist=False, ax=ax1) # just the kde plot 
ax1.set(xlabel='Distribution of temperature', title= "using only kde")

sns.distplot(df.temp, hist=False, rug=True, kde_kws={'shade':True}, ax=ax2) #kde with the rug plot and some 'Shade'
ax2.set(xlabel='Distribution of temperature', title= "using rug and some shade")

sns.despine(right=True, top=True)

# %% [markdown]
# #### 2. Box plots

# %% [markdown]
# TODO: talk about binning bias and introduce Box plot

# %%
plt.figure(figsize=(6,5))
ax = sns.boxplot(x = df.temp, orient="v", color= 'g')
ax.set(title = 'Using a box plot to show distributions', ylabel="Distribution of temprature")
# Out:
# [Text(0, 0.5, 'Distribution of temprature'),
#  Text(0.5, 1.0, 'Using a box plot to show distributions')]

# %% [markdown]
# If we want to visualize the distibution of a continuous variable across certain categories, that will require us to create one histogram per category ( in this case 12 ).
# Box plots make that easier , by sqeezing the numerous distributions across all categories into a **single** plot.
# For example, in this data, let us visualize the distribution of temperature across different months of the year where
# * continuous variable >> temperature
# * categories >> months of a year

# %%
ax = sns.boxplot(data = df, x = 'temp', y='month')
ax.set(title = "Distribution of temperature across months", xlabel= "Temperature", ylabel = "Months")
# Out:
# [Text(0, 0.5, 'Months'),
#  Text(0.5, 0, 'Temperature'),
#  Text(0.5, 1.0, 'Distribution of temperature across months')]

# %% [markdown]
# #### 3. Swarm plots

# %% [markdown]
# These are similar to box plots where they give an idea of the distribution across categories. But _unlike_ box plots which renders the summary of the column, the Swarm plots render individual data points.
# * **Note** : the position a point is rendered is not exactly its (x,y) location in the coordinate plane. Points are only jittered to allow seeing all the points at that location.

# %%
ax2 = sns.swarmplot(data = df, x = "temp", y = "month", color=".2" )
ax2.set(title = "Distribution of temperature across months", ylabel="Month", xlabel="Temperature")


#ax2 = sns.boxplot(data= df, x="temp", y="month")# run this line to overlap the box and swarm plots
# Out:
# [Text(0, 0.5, 'Month'),
#  Text(0.5, 0, 'Temperature'),
#  Text(0.5, 1.0, 'Distribution of temperature across months')]

# %% [markdown]
# #### 4. Feel some 'Joy' ..Plots
# * These help achieve the same purpose as the above box plot (i.e. distribution of one continuous variable across categories)

# %%
ignore = ['nov']
df_sub = df[~df.month.isin(ignore)].sort_values(by="Month")

labels = list(df_sub.month.unique())
fig, axes = joypy.joyplot(data = df_sub, 
                          title = "Distribution of relative humidity across all months (except nov) in a year",
                          column = "RH" ,
                          by="month", labels = labels,
                          colormap=cm.autumn_r,
                          xlim=200
                         )

# November has been excluded because there is only 1 record (forest fire) belonging to that month, and a Joyplot 
# needs multiple rows for each group.
