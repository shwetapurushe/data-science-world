# %%
import plotly
import plotly.graph_objects as go
import plotly.io as pio
import plotly.figure_factory as ff

pio.templates.default = 'plotly_dark'
pio.renderers.default = "jupyterlab"

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
import numpy as np

# %%
n_defaults = np.random.binomial(100, 0.05, 10000)

# %% [markdown]
# PMF

# %%
#1 Using Graph objects 
# fig = go.Figure(
#     data =go.Histogram(x = n_defaults),
#     layout_title_text= "PMF of n_defaults"
# )
# fig.show()

#2 Using Figure factory
fig = ff.create_distplot(
    [n_defaults],
    ["n_defaults"],
    bin_size = 1,
)
fig.update_layout(
    title_text = "Probability Mass function of a Binomial distribution",
    xaxis_title_text = "Number of defaults",
    yaxis_title_text = "PMF (density)"
)
fig.show(renderer='jupyterlab')

# %% [markdown]
# CDF

# %%
x, y = ecdf(n_defaults)

# %%
fig = go.Figure(
    data=go.Scatter(x=x, y=y, mode='lines'),
    layout_title_text='CDF with a Scatter plot',
    layout_xaxis_title ="Number of Defaults",
    layout_yaxis_title= "ECDF"
)

fig.show()

# %%
fig = go.Figure(
    data= go.Scattergl(x= x, y = y, mode='markers'),
    layout_title_text = "Plotting a CDF with ScatterGL"
)
fig.show()
