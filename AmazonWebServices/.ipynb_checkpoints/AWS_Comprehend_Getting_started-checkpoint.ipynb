# %%
import boto3

# %% [markdown]
# Before you can begin using Boto 3, you should set up AWS authentication credentials.
# * Install AWS CLI
# * log into aws account > IAM > Users > ur_user > Security Credentials > Create and download Acces key and secret
# * from AWS cli ` aws configure` using details from above

# %%
s3 = boto3.resource('s3')

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# cap-analytics-platform-lab9
# cf-templates-f2og9dns5urj-us-east-1
# elasticbeanstalk-us-east-1-684066638289
# lab9-cloudtrail
# learning-kc
# sagemaker-analytics

# %% [markdown]
# ### Getting started with Amazon Comprehend

# %%
comprehend = boto3.client(service_name='comprehend', region_name = 'us-east-1')

# %%
## Getting the dominant language

dom_language = comprehend.detect_dominant_language(Text = text)
dom_language
# Out:
# {'Languages': [{'LanguageCode': 'en', 'Score': 0.9978784322738647}],
#  'ResponseMetadata': {'RequestId': '2af1d1a6-6141-11e9-bd33-3108a9646fb0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '2af1d1a6-6141-11e9-bd33-3108a9646fb0',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '64',
#    'date': 'Wed, 17 Apr 2019 18:46:52 GMT'},
#   'RetryAttempts': 0}}

# %%
entities = comprehend.detect_entities(Text = text, LanguageCode = 'en')
# Main entity seems to be QUANTITY
# Out:
# {'Entities': [{'Score': 0.8031439781188965,
#    'Type': 'QUANTITY',
#    'Text': 'two quick examples',
#    'BeginOffset': 420,
#    'EndOffset': 438},
#   {'Score': 0.6598330736160278,
#    'Type': 'QUANTITY',
#    'Text': '5',
#    'BeginOffset': 488,
#    'EndOffset': 489},
#   {'Score': 0.8104240894317627,
#    'Type': 'QUANTITY',
#    'Text': '5',
#    'BeginOffset': 616,
#    'EndOffset': 617},
#   {'Score': 0.6949018836021423,
#    'Type': 'QUANTITY',
#    'Text': '2',
#    'BeginOffset': 653,
#    'EndOffset': 654},
#   {'Score': 0.9582775235176086,
#    'Type': 'QUANTITY',
#    'Text': '5',
#    'BeginOffset': 670,
#    'EndOffset': 671},
#   {'Score': 0.9933885335922241,
#    'Type': 'QUANTITY',
#    'Text': '2',
#    'BeginOffset': 676,
#    'EndOffset': 677},
#   {'Score': 0.6528992056846619,
#    'Type': 'QUANTITY',
#    'Text': '5',
#    'BeginOffset': 731,
#    'EndOffset': 732},
#   {'Score': 0.40538838505744934,
#    'Type': 'QUANTITY',
#    'Text': '2',
# ...

# %%
## Getting a list of entities in the text
for en in entities["Entities"]:
    print(en["Type"])
# Out:
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY
# QUANTITY

# %%
# Detecting Sentiment 
sentiment = comprehend.detect_sentiment(Text = text, LanguageCode = 'en')
sentiment
# Out:
# {'Sentiment': 'NEUTRAL',
#  'SentimentScore': {'Positive': 0.0518159456551075,
#   'Negative': 0.04941026493906975,
#   'Neutral': 0.8652091026306152,
#   'Mixed': 0.03356467932462692},
#  'ResponseMetadata': {'RequestId': '37f35416-6142-11e9-bc89-6be2ddc75b84',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '37f35416-6142-11e9-bc89-6be2ddc75b84',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '160',
#    'date': 'Wed, 17 Apr 2019 18:54:24 GMT'},
#   'RetryAttempts': 0}}

# %%
# Detect key phrases for 
key_phrases = comprehend.detect_key_phrases(Text=text, LanguageCode = 'en')
for kp in key_phrases["KeyPhrases"]:
    print(kp["Text"])
# Out:
# a few forms
# an equation
# a line
# the one
# the slope
# form
# An equation
# a line
# a slope m
# y intercept b
# mx
# our general graph
# this line
# the y intercept
# 0b
# the line
# the left
# the right
# your slope m
# two quick examples
# the equation
# a line
# slope negative 5
# 2
# The equation
# the form y
# mx
# The slope m
# negative 5
# the y intercept b
# 2
# negative 5 and 2
# our equation
# negative 5x plus 2
# the slope
# the y intercept
# the line 2y
# 3x
# 6
# the equation
# a form y
# mx
# 2y
# 3x
# 6
# 3x
# both sides
# 2y
# 3x
# 6
# 2
# 3/2x plus 3
# the form y
# mx
# 3/2
# 3
# the slope
# 3/2
# the y intercept
# 3
# the graph
# the equation
# 4x minus 2y
# 4
# 0
# the equation
# its graph
# a line
# the graph
# any two points
# the line
# The intercepts
# the easiest points
# the x intercept
# the x intercept
# 0
# the original equation
# 4x minus 4
# 0
# 4
# both sides
# 4x
# 4
# 4
# 1
# the y intercept
# the y intercept
# 0
# the equation
# minus 2y
# 4
# ...

# %%
# Syntax to get parts of speech
syntax = comprehend.detect_syntax(Text = text, LanguageCode = 'en')
syntax
# Out:
# {'SyntaxTokens': [{'TokenId': 1,
#    'Text': 'There',
#    'BeginOffset': 0,
#    'EndOffset': 5,
#    'PartOfSpeech': {'Tag': 'PRON', 'Score': 0.9998216032981873}},
#   {'TokenId': 2,
#    'Text': 'are',
#    'BeginOffset': 6,
#    'EndOffset': 9,
#    'PartOfSpeech': {'Tag': 'VERB', 'Score': 0.9994539618492126}},
#   {'TokenId': 3,
#    'Text': 'a',
#    'BeginOffset': 10,
#    'EndOffset': 11,
#    'PartOfSpeech': {'Tag': 'DET', 'Score': 0.9999971389770508}},
#   {'TokenId': 4,
#    'Text': 'few',
#    'BeginOffset': 12,
#    'EndOffset': 15,
#    'PartOfSpeech': {'Tag': 'ADJ', 'Score': 0.9999712705612183}},
#   {'TokenId': 5,
#    'Text': 'forms',
#    'BeginOffset': 16,
#    'EndOffset': 21,
#    'PartOfSpeech': {'Tag': 'NOUN', 'Score': 0.999560534954071}},
#   {'TokenId': 6,
#    'Text': 'that',
#    'BeginOffset': 22,
#    'EndOffset': 26,
#    'PartOfSpeech': {'Tag': 'PRON', 'Score': 0.9991382360458374}},
#   {'TokenId': 7,
#    'Text': 'can',
#    'BeginOffset': 27,
# ...

# %% [markdown]
# This score is a confidence metric associated with each task.
# *TODO : Determine and explain these confidence metrics.*
